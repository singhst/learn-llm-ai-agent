# %%
# !venv/bin/python test-maf-react_pattern.py
# Out:
# --- Starting MAF Agent (Ollama Qwen2.5) ---
#
# 昨天（2026年3月29日），香港的天气是Rainy，气温为19°C。

# %%
# !venv/bin/python test-maf-react_pattern-show-log.py
# Out:
# === 強制穩定監控模式 (修正版) ===
#
# 根據我的查詢結果：
#
# **您的位置：** 香港
#
# **這裡昨天（2026年3月29日）的天氣：** 雨天，氣溫 24°C
#
# 希望這個資訊對您有幫助！

# %%
# !venv/bin/python test-maf-log-opemtelemetry.py
# Out:
# === 手動包裹 OpenTelemetry 追蹤 ===
#
# 您現在位於**香港**。
#
# 根據歷史天氣數據，昨天（2026年3月29日）香港的天氣情況如下：
#
# *   **天氣狀況**：下雨
# *   **氣溫**：24°C
#
# 希望這個資訊對您有所幫助！{
#     "name": "AgentExecution",
#     "context": {
#         "trace_id": "0xda368c094611b22a84a7708631205577",
#         "span_id": "0x8640587bb411adbc",
#         "trace_state": "[]"
#     },
#     "kind": "SpanKind.INTERNAL",
#     "parent_id": null,
#     "start_time": "2026-03-29T16:58:00.042869Z",
#     "end_time": "2026-03-29T16:59:11.518131Z",
#     "status": {
#         "status_code": "UNSET"
#     },
#     "attributes": {
#         "user.query": "\u6211\u5728\u54ea\u88e1\uff1f\u9019\u88e1\u6628\u5929\u7684\u5929\u6c23\u5982\u4f55\uff1f"
#     },
#     "events": [],
#     "links": [],
#     "resource": {
#         "attributes": {
#             "telemetry.sdk.language": "python",
#             "telemetry.sdk.name": "opentelemetry",
#             "telemetry.sdk.version": "1.40.0",
#             "service.name": "unknown_service"
#         },
#         "schema_url": ""
#     }
# }
#
#
# --- 強制刷新追蹤數據 ---
